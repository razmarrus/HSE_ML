# %% [markdown]
# # Programming Assignment: decision trees

# %% [markdown]
# This notebook is practicum on the decision tree topic. We will be, once again, working with data from Titanic, that was published on [kaggle](https://www.kaggle.com/c/titanic/overview)
# In the next paragraph, original six tasks for this assignment will be presented in Russian.
#
# **Tasks will be duplicated in english further in this assignment**
#
# 1. Загрузите выборку из файла titanic.csv с помощью пакета Pandas.
# 2. Оставьте в выборке четыре признака: класс пассажира (Pclass), цену билета (Fare), возраст пассажира (Age) и его пол (Sex). Обратите внимание, что признак Sex имеет строковые значения.
# 3. Выделите целевую переменную — она записана в столбце Survived.
# 4. В данных есть пропущенные значения — например, для некоторых пассажиров неизвестен их возраст. Такие записи при чтении их в pandas принимают значение nan. Найдите все объекты, у которых есть пропущенные признаки, и удалите их из выборки.
# 5. Обучите решающее дерево с параметром random_state=241 и остальными параметрами по умолчанию (речь идет о параметрах конструктора DecisionTreeСlassifier).
# 6. Вычислите важности признаков и найдите два признака с наибольшей важностью. Их названия будут ответами для данной задачи (в качестве ответа укажите названия признаков через запятую или пробел, порядок не важен).

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import pandas

# %% [markdown]
# # Task №1
#
# *Ru*:
# Загрузите выборку из файла titanic.csv с помощью пакета Pandas
#
# *Eng*: Download sample from titanic.csv file using Pandas package

# %%
df = pandas.read_csv('titanic.csv',index_col='PassengerId')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # Task №2
#
# *Ru:* Оставьте в выборке четыре признака: класс пассажира (Pclass), цену билета (Fare), возраст пассажира (Age) и его пол (Sex). Обратите внимание, что признак Sex имеет строковые значения.
#
# *Eng*: Leave four characteristics in the table: passenger class (Pclass), ticket price (Fare), passenger's age (Age) and his gender (Sex). Note that Sex has string values.

# %%
columns_list = list(df.columns)
columns_list
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
corrected_col_list = ['Pclass', 'Fare', 'Age', 'Sex']

# %%
#df = df.set_index('Fare')

# %%
#X = df.loc[:, ["Pclass", "Fare", "Age", "Sex"]]
#X = X.dropna()

# %%
for col in df:
    if col not in corrected_col_list:
        del df[col]
df
# Out:
#              Pclass     Sex   Age     Fare
# PassengerId
# 1                 3    male  22.0   7.2500
# 2                 1  female  38.0  71.2833
# 3                 3  female  26.0   7.9250
# 4                 1  female  35.0  53.1000
# 5                 3    male  35.0   8.0500
# ...             ...     ...   ...      ...
# 887               2    male  27.0  13.0000
# 888               1  female  19.0  30.0000
# 889               3  female   NaN  23.4500
# 890               1    male  26.0  30.0000
# 891               3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %% [markdown]
# # Task №3
# *Ru*: Выделите целевую переменную — она записана в столбце Survived.
#
# *Eng*: Highlight the target variable - it is recorded in the Survived column.

# %%
Y = pandas.read_csv('titanic.csv',index_col='PassengerId')
Y = Y.dropna(subset = ["Age"])
Y
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
for col in Y:
    if col != 'Survived':
        del Y[col]
Y
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 886                 0
# 887                 0
# 888                 1
# 890                 1
# 891                 0
#
# [714 rows x 1 columns]

# %% [markdown]
# # Task № 4
# *Ru*: В данных есть пропущенные значения — например, для некоторых пассажиров неизвестен их возраст. Такие записи при чтении их в pandas принимают значение nan. Найдите все объекты, у которых есть пропущенные признаки, и удалите их из выборки.
#
# *Eng*: There are missing values in the data. For example we don't know an age of some passengers. Such records are set to nan when read into pandas. Find all objects that have missing features and remove them from the selection.

# %%
df["Sex"] = df["Sex"].map({"male": 0, "female": 1})

# %%
#X = df.loc[:, ["Pclass", "Fare", "Age", "Sex"]]
# X = X.dropna()

# %%
df = df.dropna(subset = ["Age"])

# %%
df
# Out:
#              Pclass  Sex   Age     Fare
# PassengerId
# 1                 3    0  22.0   7.2500
# 2                 1    1  38.0  71.2833
# 3                 3    1  26.0   7.9250
# 4                 1    1  35.0  53.1000
# 5                 3    0  35.0   8.0500
# ...             ...  ...   ...      ...
# 886               3    1  39.0  29.1250
# 887               2    0  27.0  13.0000
# 888               1    1  19.0  30.0000
# 890               1    0  26.0  30.0000
# 891               3    0  32.0   7.7500
#
# [714 rows x 4 columns]

# %% [markdown]
# # Task №5
# *Ru*: Обучите решающее дерево с параметром random_state=241 и остальными параметрами по умолчанию (речь идет о параметрах конструктора DecisionTreeСlassifier).
#
# *Eng*: Train the decision tree with the random_state = 241 parameter.  The rest of the parameters should be default (we are talking about the parameters of the DecisionTreeСlassifier constructor).

# %%
tree = DecisionTreeClassifier(random_state=241)
tree.fit(df, Y)
# Out:
# DecisionTreeClassifier(random_state=241)

# %% [markdown]
# # Task №6
#
# *Ru*: Вычислите важности признаков и найдите два признака с наибольшей важностью. Их названия будут ответами для данной задачи (в качестве ответа укажите названия признаков через запятую или пробел, порядок не важен).
#
# *Eng*: Calculate the importance of the attributes and find the two most important attributes. Their names will be the answers for this problem

# %%
feature_importances = pandas.Series(tree.feature_importances_, index=df.columns).sort_values(ascending=False)
feature_importances
# Out:
# Fare      0.300727
# Sex       0.300512
# Age       0.251242
# Pclass    0.147518
# dtype: float64

# %% [markdown]
# Sex, Fare
